# %% [markdown]
# # CT2FE example 02 - data visualization
# ## Kaya et al. (2019), Foams of Gray Cast Iron as Efficient Energy Absorption Structures: A Feasibility Study. <br /> Adv. Eng. Mater., 21: 1900080. https://doi.org/10.1002/adem.201900080
#
# ### CT dataset to tethraedra mesh and FE model solution in Calculix
# 23.05.2021
#
# The preprocessing of this example is performed in 3D Slicer using the extension [SlicerSegmenterMesher](https://github.com/lassoan/SlicerSegmentMesher#tutorial). <br />
# This extension of 3D Slicer allows the creation of volumetric meshes from segmented 3D data using Cleaver2 or TetGen. <br />
# The full SlicerSegmentMesher tutorial can be found here:
# https://github.com/lassoan/SlicerSegmentMesher#tutorial  <br />
# For info on the solver see the Calculix homepage:
# http://www.calculix.de/
#
# ![](test_data/example_02/IMG_20201121_225702.jpg)

# %% [markdown]
# ## Basic configurations

# %%
import os
import numpy as np
from recon_utils import read_tiff_stack, plot_midplanes
import dxchange
import matplotlib
import matplotlib.pyplot as plt
import logging
logging.basicConfig(level=logging.INFO)

matplotlib.rcParams['figure.dpi'] = 300

font = {'weight' : 'normal',
        'size'   : 8}

plt.rc('font', **font)

# %%
# %%html
# <style>
# table {float:left}
# </style>
# Out:
# <style>
# table {float:left}
# </style>

# %% [markdown]
# #### Inputs and parameters definition

# %%
input_file = '/home/gianthk/Data/TOMCAT/Kaya/D_single_h1h2_scale05/D_single_h1h2_scale050001.tif'
# filename_in, ext = os.path.split(input_file)

# %% [markdown]
# Input data description
#
# |Scan parameters|   |
# |:-|:-|
# |Beamline|TOMCAT@SLS|
# |Sample|Sintered steel foam strut from [Kaya_2016](10.1016/j.matdes.2016.05.069)|
# |Energy|34 keV|
# |Camera|PCO.edge5|
# |Optics|10x|
# |Voxel size|0.65 micron|
# |Notes|Two Z-scans merged; downsampled @ 5X and quadratic interpolation|

# %%
# Preview input 3D data
data_3D = read_tiff_stack(input_file)
plot_midplanes(data_3D)

# %% [markdown]
# Inspect the dataset with itkwidget

# %%
import itk
from itkwidgets import view
viewer = view(data_3D, ui_collapsed=True)
viewer.interpolation = False

# %%
# launch itk viewer
viewer

# %% [markdown]
# ## Pre-processing
# The following steps are performed in [3D Slicer](https://www.slicer.org/)
# - [x] **3D rotate** (**Transforms** module). Apply a rigid rotation (manual) along P-A and R-L planes to align the strut vertically.
# ![](test_data/example_02/3DSlicer_transform.png)
# - [x] **Orient Scalar Volume** (**Converters** module): Orientation: axial (NO)
# - [x] **Crop Volume** (**Converters** module): limit the model size and flattens the strut top and bottom
# - [x] **3D global threshold** (Kittler-Illingworth)
#     - [x] Smooth with closing method (fill holes)
#     - [x] Invert (twice) and remove small islands
#     - [x] Add the large pores segmented separately
#     - [x] Median smoothing
# - [x] **Segmenter Mesher**
#     - Feature scaling: 0.8
#     - Sampling rate: 0.5
#     - Rate of change el size: 0.4

# %% [markdown]
# ## Inspect the VTK mesh with ParaView

# %%
input_file_mesh = '/home/gianthk/Data/TOMCAT/Kaya/D_single_h1h2_3DSlicer/D_single.vtk' # unstructured grid VTK file exported in 3D Slicer

# %% [markdown]
# ## Modify VTK unstructured grid mesh and generate Abaqus/CalculiX input
# We need to modify the mesh in the following way: <br />
#
# - [ ] Add points sets for boundary nodes: NODES_S, NODES_N, NODES_E, NODES_W, NODES_T, NODES_B
# - [ ] Add elemets sets for boundary elements: ELEMS_S, ELEMS_N, ELEMS_E, ELEMS_W, ELEMS_T, ELEMS_B
# - [ ] Add material property section
# - [ ] Add definition of FE analysis (boudary conditions, non-linear geometry including material plasticity, quasi-static time-steps)
#
# We use the module *meshio* to import the mesh.

# %%
import meshio

# %%
# inspect the input mesh
mesh = meshio.read(input_file_mesh)
vars(mesh)
# Out:
# {'points': array([[303.579   , 306.325   , 104.5993  ],
#         [297.65    , 312.2541  ,  98.670296],
#         [303.7763  , 324.3659  , 104.6251  ],
#         ...,
#         [ 83.271996, 193.76599 , 362.8216  ],
#         [ 83.311   , 193.76599 , 365.02863 ],
#         [ 83.590996, 193.76599 , 367.2356  ]], dtype=float32),
#  'cells': [<meshio CellBlock, type: tetra, num cells: 742468>],
#  'point_data': {},
#  'cell_data': {'labels': [array([1, 1, 1, ..., 1, 1, 1], dtype=int32)]},
#  'field_data': {},
#  'point_sets': {},
#  'cell_sets': {},
#  'gmsh_periodic': None,
#  'info': None}

# %% [markdown]
# ## mesh2Abaqus.py
# The script mesh2Abaqus.py reads the .VTK unstructured grid mesh exported by 3D Slicer and converts it to Abaqus input file (.INP) for solution in Abaqus or Calculix. <br />
# The script uses the module *meshio* for read/write operations.<br />
# The *-k* flag is used with keywords *NSET* and *ELSET* to add boundary points and elements sets.<br />
# The *-t* flag is used to input a separate (.INP) text file with material properties and FE analysis definition in Abaqus syntax.<br />
#
# See the script help with the command
# `mesh2abaqus.py -h`

# %%
# %run mesh2Abaqus.py -h
# Out:
# usage: mesh2Abaqus.py [-h] [-k [KEYWORDS [KEYWORDS ...]]] [-t TEMPLATE]
#                       [-v VERBOSE]
#                       filein fileout
#
# Script to create ABAQUS Finite Element (FE) input file from 3D unstructured grid VTK mesh.
#
# The scripts converts a .VTK unstructured grid mesh file to an Abaqus .INP file.
# The output of this script is an input file (.INP) in ABAQUS syntax
# that can be solved using ABAQUS or CALCULIX.
#
# Boundary conditions (BCs), simulation steps and associated output requests
# are defined in a separate template file. See "temp.inp" for an example.
# More info at:
# https://abaqus-docs.mit.edu/2017/English/SIMACAECAERefMap/simacae-m-Sim-sb.htm#simacae-m-Sim-sb
#
# positional arguments:
#   filein                Input filename (voxel data).
#   fileout               Output filename (Abaqus .INP).
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -k [KEYWORDS [KEYWORDS ...]], --keywords [KEYWORDS [KEYWORDS ...]]
#                         Abaqus keywords.
#   -t TEMPLATE, --template TEMPLATE
#                         Template file (Abaqus syntax) defining analysis steps,
#                         boundary conditions and output requests.
#   -v VERBOSE, --verbose VERBOSE
#                         Verbose output
#
# SUPPORTED ABAQUS KEYWORDS:
#
#     For a list of all Abaqus keywords and their description visit:
#     https://abaqus-docs.mit.edu/2017/English/SIMACAECAERefMap/simacae-c-gen-kwbrowser.htm#simacae-c-gen-kwbrowser__simacae-gen-xsl-U
#
#     * 'PROPERTY' (Not supported):
#             Define an external material mapping law from template file. (Default = Yes)
#             Use in combination with '-p' ('--property') and '-r' ('--prange') flags to input
#             material property files and corresponding GV ranges for the material mapping.
#     * 'NSET':
#             Create boundary node sets. (Default = None)
#             If 'NSET' is specified, the following node sets are created:
#               - NODES_S: Nodes on SOUTH surface of 3D model.
#               - NODES_N: Nodes on NORTH surface of 3D model.
#               - NODES_E: Nodes on EAST surface of 3D model.
#               - NODES_W: Nodes on WEST surface of 3D model.
#               - NODES_T: Nodes on TOP surface of 3D model.
#               - NODES_B: Nodes on BOTTOM surface of 3D model.
#             These node sets are available for boundary conditions definition.
#     * 'ELSET':
#             Create boundary element sets. (Default = None)
#             If 'ELSET' is specified, the following element sets are created:
#               - ELEMS_S: Elements of SOUTH surface of 3D model.
#               - ELEMS_N: Elements of NORTH surface of 3D model.
#               - ELEMS_E: Elements of EAST surface of 3D model.
#               - ELEMS_W: Elements of WEST surface of 3D model.
#               - ELEMS_T: Elements of TOP surface of 3D model.
#               - ELEMS_B: Elements of BOTTOM surface of 3D model.
#
# EXAMPLES:
#
# * Convert VTk unstructured grid mesh to CalculiX FE for tensile test simulations.
#   The analysis type and all BCs and requested outputs are defined in the template file "temp_example02_tens_Nlgeom.inp":
#
#     mesh2Abaqus.py D_single.vtk CalculiX/D_single.inp
#     -k NSET ELSET
#     -t temp_example02_tens_Nlgeom.inp

# %% [markdown]
# #### Visualize template CalculiX analisys definition

# %%
# !more {template_inp}

# %% [markdown]
# ## Write Abaqus input file

# %%
filename_out = '/home/gianthk/Data/TOMCAT/Kaya/D_single_h1h2_3DSlicer/CalculiX/tens_Nlgeom/D_single2.inp'
template_inp = '/home/gianthk/PycharmProjects/CT2FE/input_templates/tmp_example02_tens_Nlgeom2.inp' # non-linear analysis; material plasticity; quasi-static tension along strut axis
# %run mesh2Abaqus.py {input_file_mesh} {filename_out} -k NSET ELSET -t {template_inp} -v True
# Out:
# INFO:root:Loaded mesh with fields:
#
# INFO:root:{'points': array([[303.579   , 306.325   , 104.5993  ],
#        [297.65    , 312.2541  ,  98.670296],
#        [303.7763  , 324.3659  , 104.6251  ],
#        ...,
#        [ 83.271996, 193.76599 , 362.8216  ],
#        [ 83.311   , 193.76599 , 365.02863 ],
#        [ 83.590996, 193.76599 , 367.2356  ]], dtype=float32), 'cells': [<meshio CellBlock, type: tetra, num cells: 742468>], 'point_data': {}, 'cell_data': {'labels': [array([1, 1, 1, ..., 1, 1, 1], dtype=int32)]}, 'field_data': {}, 'point_sets': {}, 'cell_sets': {}, 'gmsh_periodic': None, 'info': None}
# INFO:root:Reading Abaqus template file /home/gianthk/PycharmProjects/CT2FE/input_templates/tmp_example02_tens_Nlgeom2.inp
# INFO:root:Data written to file /home/gianthk/Data/TOMCAT/Kaya/D_single_h1h2_3DSlicer/CalculiX/D_single2.inp

# %% [markdown]
# ## Solve FE model in calculix
# The following section assumes that you have the Calculix solver installed and accessible with the command `ccx_2.17` or for multithread option `ccx_2.17_MT` <br />
# The multithread option in CalculiX is activated by defining the number of threads (default=1) used for the calculation.<br />
# This is done by setting the env variable *OMP_NUM_THREADS* with:
# `export OMP_NUM_THREADS=8`

# %%
# !export OMP_NUM_THREADS=8; ccx_2.17_MT {filename_out}

# %% [markdown]
# ### Convert Calculix output to Paraview
# The following sections assume that you have **ccx2paraview** and **Paraview** installed and working.<br /> For more info visit: <br />
# https://www.paraview.org/ <br />
# https://github.com/calculix/ccx2paraview

# %%
import ccx2paraview

# %%
filename_out = '/home/gianthk/Data/TOMCAT/Kaya/D_single_h1h2_3DSlicer/CalculiX/tens_Nlgeom/D_single2.inp'
filename_out_base, ext_out = os.path.splitext(filename_out)
ccx2paraview.Converter(filename_out_base + '.frd', ['vtk']).run()
# Out:
# INFO:root:Reading D_single2.frd
# INFO:root:162247 nodes
# INFO:root:742468 cells
# INFO:root:Step 1, time 5.00e-02, U, 3 components, 162247 values
# INFO:root:Step 1, time 5.00e-02, S, 6 components, 162247 values
# INFO:root:Step 1, time 5.00e-02, PEEQ, 1 components, 162247 values
# INFO:root:Step 1, time 5.00e-02, ERROR, 1 components, 162247 values
# INFO:root:Step 2, time 1.00e-01, U, 3 components, 162247 values
# INFO:root:Step 2, time 1.00e-01, S, 6 components, 162247 values
# INFO:root:Step 2, time 1.00e-01, PEEQ, 1 components, 162247 values
# INFO:root:Step 2, time 1.00e-01, ERROR, 1 components, 162247 values
# INFO:root:Step 3, time 1.50e-01, U, 3 components, 162247 values
# INFO:root:Step 3, time 1.50e-01, S, 6 components, 162247 values
# INFO:root:Step 3, time 1.50e-01, PEEQ, 1 components, 162247 values
# INFO:root:Step 3, time 1.50e-01, ERROR, 1 components, 162247 values
# INFO:root:Step 4, time 2.00e-01, U, 3 components, 162247 values
# INFO:root:Step 4, time 2.00e-01, S, 6 components, 162247 values
# INFO:root:Step 4, time 2.00e-01, PEEQ, 1 components, 162247 values
# INFO:root:Step 4, time 2.00e-01, ERROR, 1 components, 162247 values
# INFO:root:Step 5, time 2.50e-01, U, 3 components, 162247 values
# INFO:root:Step 5, time 2.50e-01, S, 6 components, 162247 values
# INFO:root:Step 5, time 2.50e-01, PEEQ, 1 components, 162247 values
# INFO:root:Step 5, time 2.50e-01, ERROR, 1 components, 162247 values
# INFO:root:Step 6, time 3.00e-01, U, 3 components, 162247 values
# INFO:root:Step 6, time 3.00e-01, S, 6 components, 162247 values
# INFO:root:Step 6, time 3.00e-01, PEEQ, 1 components, 162247 values
# INFO:root:Step 6, time 3.00e-01, ERROR, 1 components, 162247 values
# INFO:root:Step 7, time 3.50e-01, U, 3 components, 162247 values
# INFO:root:Step 7, time 3.50e-01, S, 6 components, 162247 values
# INFO:root:Step 7, time 3.50e-01, PEEQ, 1 components, 162247 values
# INFO:root:Step 7, time 3.50e-01, ERROR, 1 components, 162247 values
# INFO:root:Step 8, time 4.00e-01, U, 3 components, 162247 values
# INFO:root:Step 8, time 4.00e-01, S, 6 components, 162247 values
# INFO:root:Step 8, time 4.00e-01, PEEQ, 1 components, 162247 values
# INFO:root:Step 8, time 4.00e-01, ERROR, 1 components, 162247 values
# INFO:root:Step 9, time 4.50e-01, U, 3 components, 162247 values
# INFO:root:Step 9, time 4.50e-01, S, 6 components, 162247 values
# INFO:root:Step 9, time 4.50e-01, PEEQ, 1 components, 162247 values
# INFO:root:Step 9, time 4.50e-01, ERROR, 1 components, 162247 values
# INFO:root:Step 10, time 5.00e-01, U, 3 components, 162247 values
# INFO:root:Step 10, time 5.00e-01, S, 6 components, 162247 values
# INFO:root:Step 10, time 5.00e-01, PEEQ, 1 components, 162247 values
# INFO:root:Step 10, time 5.00e-01, ERROR, 1 components, 162247 values
# INFO:root:Step 11, time 5.50e-01, U, 3 components, 162247 values
# INFO:root:Step 11, time 5.50e-01, S, 6 components, 162247 values
# INFO:root:Step 11, time 5.50e-01, PEEQ, 1 components, 162247 values
# INFO:root:Step 11, time 5.50e-01, ERROR, 1 components, 162247 values
# INFO:root:Step 12, time 6.00e-01, U, 3 components, 162247 values
# INFO:root:Step 12, time 6.00e-01, S, 6 components, 162247 values
# INFO:root:Step 12, time 6.00e-01, PEEQ, 1 components, 162247 values
# INFO:root:Step 12, time 6.00e-01, ERROR, 1 components, 162247 values
# INFO:root:Step 13, time 6.50e-01, U, 3 components, 162247 values
# INFO:root:Step 13, time 6.50e-01, S, 6 components, 162247 values
# INFO:root:Step 13, time 6.50e-01, PEEQ, 1 components, 162247 values
# INFO:root:Step 13, time 6.50e-01, ERROR, 1 components, 162247 values
# INFO:root:Step 14, time 7.00e-01, U, 3 components, 162247 values
# INFO:root:Step 14, time 7.00e-01, S, 6 components, 162247 values
# INFO:root:Step 14, time 7.00e-01, PEEQ, 1 components, 162247 values
# INFO:root:Step 14, time 7.00e-01, ERROR, 1 components, 162247 values
# INFO:root:Step 15, time 7.50e-01, U, 3 components, 162247 values
# INFO:root:Step 15, time 7.50e-01, S, 6 components, 162247 values
# INFO:root:Step 15, time 7.50e-01, PEEQ, 1 components, 162247 values
# INFO:root:Step 15, time 7.50e-01, ERROR, 1 components, 162247 values
# INFO:root:Step 16, time 8.00e-01, U, 3 components, 162247 values
# INFO:root:Step 16, time 8.00e-01, S, 6 components, 162247 values
# INFO:root:Step 16, time 8.00e-01, PEEQ, 1 components, 162247 values
# INFO:root:Step 16, time 8.00e-01, ERROR, 1 components, 162247 values
# INFO:root:Step 17, time 8.50e-01, U, 3 components, 162247 values
# INFO:root:Step 17, time 8.50e-01, S, 6 components, 162247 values
# INFO:root:Step 17, time 8.50e-01, PEEQ, 1 components, 162247 values
# INFO:root:Step 17, time 8.50e-01, ERROR, 1 components, 162247 values
# INFO:root:Step 18, time 9.00e-01, U, 3 components, 162247 values
# INFO:root:Step 18, time 9.00e-01, S, 6 components, 162247 values
# INFO:root:Step 18, time 9.00e-01, PEEQ, 1 components, 162247 values
# INFO:root:Step 18, time 9.00e-01, ERROR, 1 components, 162247 values
# INFO:root:Step 19, time 9.50e-01, U, 3 components, 162247 values
# INFO:root:Step 19, time 9.50e-01, S, 6 components, 162247 values
# INFO:root:Step 19, time 9.50e-01, PEEQ, 1 components, 162247 values
# INFO:root:Step 19, time 9.50e-01, ERROR, 1 components, 162247 values
# INFO:root:Step 20, time 1.0, U, 3 components, 162247 values
# INFO:root:Step 20, time 1.0, S, 6 components, 162247 values
# INFO:root:Step 20, time 1.0, PEEQ, 1 components, 162247 values
# INFO:root:Step 20, time 1.0, ERROR, 1 components, 162247 values
# INFO:root:20 time increments
# INFO:root:Writing D_single2.01.vtk
# INFO:root:Step 1, time 5.00e-02, U, 3 components, 162247 values
# INFO:root:Step 1, time 5.00e-02, S, 6 components, 162247 values
# INFO:root:Step 1, time 5.00e-02, S_Mises, 1 components, 162247 values
# INFO:root:Step 1, time 5.00e-02, S_Principal, 3 components, 162247 values
# INFO:root:Step 1, time 5.00e-02, PEEQ, 1 components, 162247 values
# INFO:root:Step 1, time 5.00e-02, ERROR, 1 components, 162247 values
# INFO:root:Writing D_single2.02.vtk
# INFO:root:Step 2, time 1.00e-01, U, 3 components, 162247 values
# INFO:root:Step 2, time 1.00e-01, S, 6 components, 162247 values
# INFO:root:Step 2, time 1.00e-01, S_Mises, 1 components, 162247 values
# INFO:root:Step 2, time 1.00e-01, S_Principal, 3 components, 162247 values
# INFO:root:Step 2, time 1.00e-01, PEEQ, 1 components, 162247 values
# INFO:root:Step 2, time 1.00e-01, ERROR, 1 components, 162247 values
# INFO:root:Writing D_single2.03.vtk
# INFO:root:Step 3, time 1.50e-01, U, 3 components, 162247 values
# INFO:root:Step 3, time 1.50e-01, S, 6 components, 162247 values
# INFO:root:Step 3, time 1.50e-01, S_Mises, 1 components, 162247 values
# INFO:root:Step 3, time 1.50e-01, S_Principal, 3 components, 162247 values
# INFO:root:Step 3, time 1.50e-01, PEEQ, 1 components, 162247 values
# INFO:root:Step 3, time 1.50e-01, ERROR, 1 components, 162247 values
# INFO:root:Writing D_single2.04.vtk
# INFO:root:Step 4, time 2.00e-01, U, 3 components, 162247 values
# INFO:root:Step 4, time 2.00e-01, S, 6 components, 162247 values
# INFO:root:Step 4, time 2.00e-01, S_Mises, 1 components, 162247 values
# INFO:root:Step 4, time 2.00e-01, S_Principal, 3 components, 162247 values
# INFO:root:Step 4, time 2.00e-01, PEEQ, 1 components, 162247 values
# INFO:root:Step 4, time 2.00e-01, ERROR, 1 components, 162247 values
# INFO:root:Writing D_single2.05.vtk
# INFO:root:Step 5, time 2.50e-01, U, 3 components, 162247 values
# INFO:root:Step 5, time 2.50e-01, S, 6 components, 162247 values
# INFO:root:Step 5, time 2.50e-01, S_Mises, 1 components, 162247 values
# INFO:root:Step 5, time 2.50e-01, S_Principal, 3 components, 162247 values
# INFO:root:Step 5, time 2.50e-01, PEEQ, 1 components, 162247 values
# INFO:root:Step 5, time 2.50e-01, ERROR, 1 components, 162247 values
# INFO:root:Writing D_single2.06.vtk
# INFO:root:Step 6, time 3.00e-01, U, 3 components, 162247 values
# INFO:root:Step 6, time 3.00e-01, S, 6 components, 162247 values
# INFO:root:Step 6, time 3.00e-01, S_Mises, 1 components, 162247 values
# INFO:root:Step 6, time 3.00e-01, S_Principal, 3 components, 162247 values
# INFO:root:Step 6, time 3.00e-01, PEEQ, 1 components, 162247 values
# INFO:root:Step 6, time 3.00e-01, ERROR, 1 components, 162247 values
# INFO:root:Writing D_single2.07.vtk
# INFO:root:Step 7, time 3.50e-01, U, 3 components, 162247 values
# INFO:root:Step 7, time 3.50e-01, S, 6 components, 162247 values
# INFO:root:Step 7, time 3.50e-01, S_Mises, 1 components, 162247 values
# INFO:root:Step 7, time 3.50e-01, S_Principal, 3 components, 162247 values
# INFO:root:Step 7, time 3.50e-01, PEEQ, 1 components, 162247 values
# INFO:root:Step 7, time 3.50e-01, ERROR, 1 components, 162247 values
# INFO:root:Writing D_single2.08.vtk
# INFO:root:Step 8, time 4.00e-01, U, 3 components, 162247 values
# INFO:root:Step 8, time 4.00e-01, S, 6 components, 162247 values
# INFO:root:Step 8, time 4.00e-01, S_Mises, 1 components, 162247 values
# INFO:root:Step 8, time 4.00e-01, S_Principal, 3 components, 162247 values
# INFO:root:Step 8, time 4.00e-01, PEEQ, 1 components, 162247 values
# INFO:root:Step 8, time 4.00e-01, ERROR, 1 components, 162247 values
# INFO:root:Writing D_single2.09.vtk
# INFO:root:Step 9, time 4.50e-01, U, 3 components, 162247 values
# INFO:root:Step 9, time 4.50e-01, S, 6 components, 162247 values
# INFO:root:Step 9, time 4.50e-01, S_Mises, 1 components, 162247 values
# INFO:root:Step 9, time 4.50e-01, S_Principal, 3 components, 162247 values
# INFO:root:Step 9, time 4.50e-01, PEEQ, 1 components, 162247 values
# INFO:root:Step 9, time 4.50e-01, ERROR, 1 components, 162247 values
# INFO:root:Writing D_single2.10.vtk
# INFO:root:Step 10, time 5.00e-01, U, 3 components, 162247 values
# INFO:root:Step 10, time 5.00e-01, S, 6 components, 162247 values
# INFO:root:Step 10, time 5.00e-01, S_Mises, 1 components, 162247 values
# INFO:root:Step 10, time 5.00e-01, S_Principal, 3 components, 162247 values
# INFO:root:Step 10, time 5.00e-01, PEEQ, 1 components, 162247 values
# INFO:root:Step 10, time 5.00e-01, ERROR, 1 components, 162247 values
# INFO:root:Writing D_single2.11.vtk
# INFO:root:Step 11, time 5.50e-01, U, 3 components, 162247 values
# INFO:root:Step 11, time 5.50e-01, S, 6 components, 162247 values
# INFO:root:Step 11, time 5.50e-01, S_Mises, 1 components, 162247 values
# INFO:root:Step 11, time 5.50e-01, S_Principal, 3 components, 162247 values
# INFO:root:Step 11, time 5.50e-01, PEEQ, 1 components, 162247 values
# INFO:root:Step 11, time 5.50e-01, ERROR, 1 components, 162247 values
# INFO:root:Writing D_single2.12.vtk
# INFO:root:Step 12, time 6.00e-01, U, 3 components, 162247 values
# INFO:root:Step 12, time 6.00e-01, S, 6 components, 162247 values
# INFO:root:Step 12, time 6.00e-01, S_Mises, 1 components, 162247 values
# INFO:root:Step 12, time 6.00e-01, S_Principal, 3 components, 162247 values
# INFO:root:Step 12, time 6.00e-01, PEEQ, 1 components, 162247 values
# INFO:root:Step 12, time 6.00e-01, ERROR, 1 components, 162247 values
# INFO:root:Writing D_single2.13.vtk
# INFO:root:Step 13, time 6.50e-01, U, 3 components, 162247 values
# INFO:root:Step 13, time 6.50e-01, S, 6 components, 162247 values
# INFO:root:Step 13, time 6.50e-01, S_Mises, 1 components, 162247 values
# INFO:root:Step 13, time 6.50e-01, S_Principal, 3 components, 162247 values
# INFO:root:Step 13, time 6.50e-01, PEEQ, 1 components, 162247 values
# INFO:root:Step 13, time 6.50e-01, ERROR, 1 components, 162247 values
# INFO:root:Writing D_single2.14.vtk
# INFO:root:Step 14, time 7.00e-01, U, 3 components, 162247 values
# INFO:root:Step 14, time 7.00e-01, S, 6 components, 162247 values
# INFO:root:Step 14, time 7.00e-01, S_Mises, 1 components, 162247 values
# INFO:root:Step 14, time 7.00e-01, S_Principal, 3 components, 162247 values
# INFO:root:Step 14, time 7.00e-01, PEEQ, 1 components, 162247 values
# INFO:root:Step 14, time 7.00e-01, ERROR, 1 components, 162247 values
# INFO:root:Writing D_single2.15.vtk
# INFO:root:Step 15, time 7.50e-01, U, 3 components, 162247 values
# INFO:root:Step 15, time 7.50e-01, S, 6 components, 162247 values
# INFO:root:Step 15, time 7.50e-01, S_Mises, 1 components, 162247 values
# INFO:root:Step 15, time 7.50e-01, S_Principal, 3 components, 162247 values
# INFO:root:Step 15, time 7.50e-01, PEEQ, 1 components, 162247 values
# INFO:root:Step 15, time 7.50e-01, ERROR, 1 components, 162247 values
# INFO:root:Writing D_single2.16.vtk
# INFO:root:Step 16, time 8.00e-01, U, 3 components, 162247 values
# INFO:root:Step 16, time 8.00e-01, S, 6 components, 162247 values
# INFO:root:Step 16, time 8.00e-01, S_Mises, 1 components, 162247 values
# INFO:root:Step 16, time 8.00e-01, S_Principal, 3 components, 162247 values
# INFO:root:Step 16, time 8.00e-01, PEEQ, 1 components, 162247 values
# INFO:root:Step 16, time 8.00e-01, ERROR, 1 components, 162247 values
# INFO:root:Writing D_single2.17.vtk
# INFO:root:Step 17, time 8.50e-01, U, 3 components, 162247 values
# INFO:root:Step 17, time 8.50e-01, S, 6 components, 162247 values
# INFO:root:Step 17, time 8.50e-01, S_Mises, 1 components, 162247 values
# INFO:root:Step 17, time 8.50e-01, S_Principal, 3 components, 162247 values
# INFO:root:Step 17, time 8.50e-01, PEEQ, 1 components, 162247 values
# INFO:root:Step 17, time 8.50e-01, ERROR, 1 components, 162247 values
# INFO:root:Writing D_single2.18.vtk
# INFO:root:Step 18, time 9.00e-01, U, 3 components, 162247 values
# INFO:root:Step 18, time 9.00e-01, S, 6 components, 162247 values
# INFO:root:Step 18, time 9.00e-01, S_Mises, 1 components, 162247 values
# INFO:root:Step 18, time 9.00e-01, S_Principal, 3 components, 162247 values
# INFO:root:Step 18, time 9.00e-01, PEEQ, 1 components, 162247 values
# INFO:root:Step 18, time 9.00e-01, ERROR, 1 components, 162247 values
# INFO:root:Writing D_single2.19.vtk
# INFO:root:Step 19, time 9.50e-01, U, 3 components, 162247 values
# INFO:root:Step 19, time 9.50e-01, S, 6 components, 162247 values
# INFO:root:Step 19, time 9.50e-01, S_Mises, 1 components, 162247 values
# INFO:root:Step 19, time 9.50e-01, S_Principal, 3 components, 162247 values
# INFO:root:Step 19, time 9.50e-01, PEEQ, 1 components, 162247 values
# INFO:root:Step 19, time 9.50e-01, ERROR, 1 components, 162247 values
# INFO:root:Writing D_single2.20.vtk
# INFO:root:Step 20, time 1.0, U, 3 components, 162247 values
# INFO:root:Step 20, time 1.0, S, 6 components, 162247 values
# INFO:root:Step 20, time 1.0, S_Mises, 1 components, 162247 values
# INFO:root:Step 20, time 1.0, S_Principal, 3 components, 162247 values
# INFO:root:Step 20, time 1.0, PEEQ, 1 components, 162247 values
# INFO:root:Step 20, time 1.0, ERROR, 1 components, 162247 values

# %% [markdown]
# #### Visualize results in Paraview
# **PEEQ** is an integrated measure of plastic strain.

# %%
# !paraview filename_out_base + '.vtk'

# %% [markdown]
# ![](test_data/example_02/D_single_tens_Nlgeom.png)
